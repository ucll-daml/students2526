# %% [markdown]
# <img src="images\Logo_UCLL_ENG_RGB.png" style="background-color:white;" />
#
# # Data Analytics & Machine learning
#
# Lecturers: Aimée Lynn Backiel, Kenrick Borgelioen, Sofie Torfs, Lies Bollens
#
# Academic year 2025-2026
#
# ## Virtual Environment Setup (for exams)

# %% [markdown]
# We've created this mini-notebook to make it easier to setup your virtual environment for the exam.
#
# If you have a working virtual environment, you don't need to do anything here.
#
# If you don't have a virtual working environment, you can create a new one and use the code here to install any necessary packages.

# %% [markdown]
# If you need to setup your virtual environment in VS Code, there is excellent documentation available to guide you: https://code.visualstudio.com/docs/python/environments

# %% [markdown]
# Uncomment the code block below if you need to install the packages necessary for DAML in your (new) virtual environment.

# %%
# %pip install pandas
# %pip install seaborn
# %pip install plotly
# %pip install -U scikit-learn
# %pip install nbformat --update
    # you need to restart your kernel after updating nbformat

# %% [markdown]
# These import statements make the packages available for you to use in this notebook. These statements are likely useful for the exam, but you can also run the code block here to make sure all the packages are successfully installed.

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import plotly.express as px

# %% [markdown]
# It is your responsibility to have a working environment with the necessary packages to complete your take-home exam assignment. It's highly recommended to test this out *before* the end of the semester. Do not wait until you receive the assignment to check to make sure you can complete it. As the lecturers have multiple exams to organize, it is not possible to get help with your setup during the exam period.
